# %%
import warnings
warnings.filterwarnings("ignore")

import mlflow
import numpy as np

from utils.evaluate_v2 import compare_result, calculate_diff

mlflow.set_tracking_uri("/Users/pongpanod.san.adm/Desktop/Pongpanod.san/chula/pun_master_thesis/mlruns")

# %%
query_list = []

for i in list(range(1, 10)):
    query_list.append({"augment_name":"window_warp", "augment_params":{"window_ratio": i/10}, "concat_original": False})

df = compare_result(query_list, 'minirocket',['baseline'], 0.0)
df
# Out:
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# Warning: Dataset is accuracy missing
# []
# <style type="text/css">
# #T_aac75_row0_col5, #T_aac75_row0_col7, #T_aac75_row0_col9, #T_aac75_row0_col15, #T_aac75_row0_col18, #T_aac75_row0_col19, #T_aac75_row0_col28, #T_aac75_row0_col35, #T_aac75_row0_col36, #T_aac75_row0_col37, #T_aac75_row0_col40, #T_aac75_row0_col43, #T_aac75_row0_col50, #T_aac75_row0_col53, #T_aac75_row0_col54, #T_aac75_row0_col55, #T_aac75_row0_col63, #T_aac75_row0_col64, #T_aac75_row0_col70, #T_aac75_row0_col72, #T_aac75_row0_col79, #T_aac75_row0_col81, #T_aac75_row0_col82, #T_aac75_row1_col3, #T_aac75_row1_col5, #T_aac75_row1_col17, #T_aac75_row1_col22, #T_aac75_row1_col30, #T_aac75_row1_col54, #T_aac75_row1_col62, #T_aac75_row1_col68, #T_aac75_row1_col70, #T_aac75_row1_col72, #T_aac75_row2_col3, #T_aac75_row2_col31, #T_aac75_row2_col39, #T_aac75_row2_col72, #T_aac75_row3_col3, #T_aac75_row3_col5, #T_aac75_row3_col19, #T_aac75_row3_col21, #T_aac75_row3_col34, #T_aac75_row3_col54, #T_aac75_row3_col72, #T_aac75_row4_col4, #T_aac75_row4_col5, #T_aac75_row4_col9, #T_aac75_row4_col14, #T_aac75_row4_col19, #T_aac75_row4_col29, #T_aac75_row4_col54, #T_aac75_row4_col72, #T_aac75_row5_col10, #T_aac75_row5_col38, #T_aac75_row5_col39, #T_aac75_row5_col44, #T_aac75_row5_col54, #T_aac75_row5_col65, #T_aac75_row5_col72, #T_aac75_row5_col83, #T_aac75_row6_col4, #T_aac75_row6_col9, #T_aac75_row6_col16, #T_aac75_row6_col20, #T_aac75_row6_col21, #T_aac75_row6_col44, #T_aac75_row6_col54, #T_aac75_row6_col71, #T_aac75_row6_col72, #T_aac75_row7_col2, #T_aac75_row7_col5, #T_aac75_row7_col11, #T_aac75_row7_col16, #T_aac75_row7_col27, #T_aac75_row7_col42, #T_aac75_row7_col46, #T_aac75_row7_col47, #T_aac75_row7_col51, #T_aac75_row7_col54, #T_aac75_row7_col59, #T_aac75_row7_col71, #T_aac75_row7_col72, #T_aac75_row7_col83, #T_aac75_row8_col0, #T_aac75_row8_col1, #T_aac75_row8_col2, #T_aac75_row8_col6, #T_aac75_row8_col8, #T_aac75_row8_col9, #T_aac75_row8_col12, #T_aac75_row8_col13, #T_aac75_row8_col19, #T_aac75_row8_col23, #T_aac75_row8_col24, #T_aac75_row8_col25, #T_aac75_row8_col26, #T_aac75_row8_col27, #T_aac75_row8_col30, #T_aac75_row8_col32, #T_aac75_row8_col33, #T_aac75_row8_col35, #T_aac75_row8_col41, #T_aac75_row8_col45, #T_aac75_row8_col48, #T_aac75_row8_col49, #T_aac75_row8_col50, #T_aac75_row8_col51, #T_aac75_row8_col52, #T_aac75_row8_col54, #T_aac75_row8_col56, #T_aac75_row8_col57, #T_aac75_row8_col58, #T_aac75_row8_col60, #T_aac75_row8_col61, #T_aac75_row8_col65, #T_aac75_row8_col66, #T_aac75_row8_col67, #T_aac75_row8_col69, #T_aac75_row8_col72, #T_aac75_row8_col73, #T_aac75_row8_col74, #T_aac75_row8_col75, #T_aac75_row8_col76, #T_aac75_row8_col77, #T_aac75_row8_col78, #T_aac75_row8_col79, #T_aac75_row8_col80, #T_aac75_row8_col84 {
#   background-color: darkblue;
# }
# </style>
# <table id="T_aac75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aac75_level0_col0" class="col_heading level0 col0" >Adiac</th>
#       <th id="T_aac75_level0_col1" class="col_heading level0 col1" >ArrowHead</th>
#       <th id="T_aac75_level0_col2" class="col_heading level0 col2" >Beef</th>
#       <th id="T_aac75_level0_col3" class="col_heading level0 col3" >BeetleFly</th>
#       <th id="T_aac75_level0_col4" class="col_heading level0 col4" >BirdChicken</th>
#       <th id="T_aac75_level0_col5" class="col_heading level0 col5" >CBF</th>
#       <th id="T_aac75_level0_col6" class="col_heading level0 col6" >Car</th>
#       <th id="T_aac75_level0_col7" class="col_heading level0 col7" >ChlorineConcentration</th>
#       <th id="T_aac75_level0_col8" class="col_heading level0 col8" >CinCECGTorso</th>
#       <th id="T_aac75_level0_col9" class="col_heading level0 col9" >Coffee</th>
#       <th id="T_aac75_level0_col10" class="col_heading level0 col10" >Computers</th>
#       <th id="T_aac75_level0_col11" class="col_heading level0 col11" >CricketX</th>
#       <th id="T_aac75_level0_col12" class="col_heading level0 col12" >CricketY</th>
#       <th id="T_aac75_level0_col13" class="col_heading level0 col13" >CricketZ</th>
#       <th id="T_aac75_level0_col14" class="col_heading level0 col14" >DiatomSizeReduction</th>
#       <th id="T_aac75_level0_col15" class="col_heading level0 col15" >DistalPhalanxOutlineAgeGroup</th>
#       <th id="T_aac75_level0_col16" class="col_heading level0 col16" >DistalPhalanxOutlineCorrect</th>
#       <th id="T_aac75_level0_col17" class="col_heading level0 col17" >DistalPhalanxTW</th>
#       <th id="T_aac75_level0_col18" class="col_heading level0 col18" >ECG200</th>
#       <th id="T_aac75_level0_col19" class="col_heading level0 col19" >ECG5000</th>
#       <th id="T_aac75_level0_col20" class="col_heading level0 col20" >ECGFiveDays</th>
#       <th id="T_aac75_level0_col21" class="col_heading level0 col21" >Earthquakes</th>
#       <th id="T_aac75_level0_col22" class="col_heading level0 col22" >ElectricDevices</th>
#       <th id="T_aac75_level0_col23" class="col_heading level0 col23" >FaceAll</th>
#       <th id="T_aac75_level0_col24" class="col_heading level0 col24" >FaceFour</th>
#       <th id="T_aac75_level0_col25" class="col_heading level0 col25" >FacesUCR</th>
#       <th id="T_aac75_level0_col26" class="col_heading level0 col26" >FiftyWords</th>
#       <th id="T_aac75_level0_col27" class="col_heading level0 col27" >Fish</th>
#       <th id="T_aac75_level0_col28" class="col_heading level0 col28" >FordA</th>
#       <th id="T_aac75_level0_col29" class="col_heading level0 col29" >FordB</th>
#       <th id="T_aac75_level0_col30" class="col_heading level0 col30" >GunPoint</th>
#       <th id="T_aac75_level0_col31" class="col_heading level0 col31" >Ham</th>
#       <th id="T_aac75_level0_col32" class="col_heading level0 col32" >HandOutlines</th>
#       <th id="T_aac75_level0_col33" class="col_heading level0 col33" >Haptics</th>
#       <th id="T_aac75_level0_col34" class="col_heading level0 col34" >Herring</th>
#       <th id="T_aac75_level0_col35" class="col_heading level0 col35" >InlineSkate</th>
#       <th id="T_aac75_level0_col36" class="col_heading level0 col36" >InsectWingbeatSound</th>
#       <th id="T_aac75_level0_col37" class="col_heading level0 col37" >ItalyPowerDemand</th>
#       <th id="T_aac75_level0_col38" class="col_heading level0 col38" >LargeKitchenAppliances</th>
#       <th id="T_aac75_level0_col39" class="col_heading level0 col39" >Lightning2</th>
#       <th id="T_aac75_level0_col40" class="col_heading level0 col40" >Lightning7</th>
#       <th id="T_aac75_level0_col41" class="col_heading level0 col41" >Mallat</th>
#       <th id="T_aac75_level0_col42" class="col_heading level0 col42" >Meat</th>
#       <th id="T_aac75_level0_col43" class="col_heading level0 col43" >MedicalImages</th>
#       <th id="T_aac75_level0_col44" class="col_heading level0 col44" >MiddlePhalanxOutlineAgeGroup</th>
#       <th id="T_aac75_level0_col45" class="col_heading level0 col45" >MiddlePhalanxOutlineCorrect</th>
#       <th id="T_aac75_level0_col46" class="col_heading level0 col46" >MiddlePhalanxTW</th>
#       <th id="T_aac75_level0_col47" class="col_heading level0 col47" >MoteStrain</th>
#       <th id="T_aac75_level0_col48" class="col_heading level0 col48" >NonInvasiveFetalECGThorax1</th>
#       <th id="T_aac75_level0_col49" class="col_heading level0 col49" >NonInvasiveFetalECGThorax2</th>
#       <th id="T_aac75_level0_col50" class="col_heading level0 col50" >OSULeaf</th>
#       <th id="T_aac75_level0_col51" class="col_heading level0 col51" >OliveOil</th>
#       <th id="T_aac75_level0_col52" class="col_heading level0 col52" >PhalangesOutlinesCorrect</th>
#       <th id="T_aac75_level0_col53" class="col_heading level0 col53" >Phoneme</th>
#       <th id="T_aac75_level0_col54" class="col_heading level0 col54" >Plane</th>
#       <th id="T_aac75_level0_col55" class="col_heading level0 col55" >ProximalPhalanxOutlineAgeGroup</th>
#       <th id="T_aac75_level0_col56" class="col_heading level0 col56" >ProximalPhalanxOutlineCorrect</th>
#       <th id="T_aac75_level0_col57" class="col_heading level0 col57" >ProximalPhalanxTW</th>
#       <th id="T_aac75_level0_col58" class="col_heading level0 col58" >RefrigerationDev

# %%
query_list = []
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":1}, "concat_original": True})
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":3}, "concat_original": True})
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":5}, "concat_original": True})
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":7}, "concat_original": True})
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":9}, "concat_original": True})

for i in [16, 32, 64, 128, 256, 512]:
    query_list.append({"augment_name":"fourier_transform", "augment_params":{"sampling_rate_mul": 2, "n": i}, "concat_original": False})

df = compare_result(query_list, 'minirocket',['baseline'], 0.0)
df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 11
#       8 for i in [16, 32, 64, 128, 256, 512]:
#       9     query_list.append({"augment_name":"fourier_transform", "augment_params":{"sampling_rate_mul": 2, "n": i}, "concat_original": False})
# ---> 11 df = compare_result(query_list, 'minirocket',['baseline'], 0.0)
#      12 df
#
# File ~/Desktop/Pongpanod.san/chula/pun_master_thesis/utils/evaluate_v2.py:73, in compare_result(query_list, model_name, compare_with, dataset_selection)
#      70 all_variation_acc_list = []
#      71 for i in query_list:
#      72     # Query each augmented variation result
# ---> 73     query_result = query_augmented_result(
#      74         i["augment_name"], i["augment_params"], i["concat_original"], model_name
#      75     )
#      76     acc = clean(query_result, datasets)
#      78     all_acc = {}
#
# File ~/Desktop/Pongpanod.san/chula/pun_master_thesis/utils/evaluate_v2.py:36, in query_augmented_result(augment_name, augment_params, concat_original, model_name)
#      34 filter_string = construct_filter_string(augment_name, augment_params, concat_original)
#      35 runs = query_runs(filter_string)
# ---> 36 runs = filter_model(model_name, runs)
#      37 return runs
#
# File ~/Desktop/Pongpanod.san/chula/pun_master_thesis/utils/evaluate_v2.py:261, in filter_model(model_name, mlflow_runs)
#     258         result.append(run)
#     260 if result == []:
# --> 261     raise Exception("Model name not found")
#     263 return result
#
# Exception: Model name not found

# %%
query_list = []
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":1}, "concat_original": True})
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":3}, "concat_original": True})
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":5}, "concat_original": True})
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":7}, "concat_original": True})
# query_list.append({"augment_name":"window_warping", "augment_params":{"sigma": 0.1, "knot":9}, "concat_original": True})

for i in list(range(1, 10, 1)):
    query_list.append({"augment_name":"window_warping", "augment_params":{"window_ratio": i/10}, "concat_original": False})

df = compare_result(query_list, 'minirocket',['baseline'], 0.0)
df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 11
#       8 for i in list(range(1, 10, 1)):
#       9     query_list.append({"augment_name":"window_warping", "augment_params":{"window_ratio": i/10}, "concat_original": False})
# ---> 11 df = compare_result(query_list, 'minirocket',['baseline'], 0.0)
#      12 df
#
# File ~/Desktop/Pongpanod.san/chula/pun_master_thesis/utils/evaluate_v2.py:73, in compare_result(query_list, model_name, compare_with, dataset_selection)
#      70 all_variation_acc_list = []
#      71 for i in query_list:
#      72     # Query each augmented variation result
# ---> 73     query_result = query_augmented_result(
#      74         i["augment_name"], i["augment_params"], i["concat_original"], model_name
#      75     )
#      76     acc = clean(query_result, datasets)
#      78     all_acc = {}
#
# File ~/Desktop/Pongpanod.san/chula/pun_master_thesis/utils/evaluate_v2.py:36, in query_augmented_result(augment_name, augment_params, concat_original, model_name)
#      34 filter_string = construct_filter_string(augment_name, augment_params, concat_original)
#      35 runs = query_runs(filter_string)
# ---> 36 runs = filter_model(model_name, runs)
#      37 return runs
#
# File ~/Desktop/Pongpanod.san/chula/pun_master_thesis/utils/evaluate_v2.py:261, in filter_model(model_name, mlflow_runs)
#     258         result.append(run)
#     260 if result == []:
# --> 261     raise Exception("Model name not found")
#     263 return result
#
# Exception: Model name not found
