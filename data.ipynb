# %%
import pandas as pd

def query_hc(datasets: list) -> dict: 
    df = pd.read_csv('Data/SOTA-DefaultTrainTest.csv', index_col=0)
    hc2 = df["HC2"]

    result = {}
    for data in datasets:
        result[data] = hc2[data]

    return data

# %%
sota = pd.read_csv('Data/SOTA-DefaultTrainTest.csv')
summary = pd.read_csv('Data/DataSummary.csv')

# %%
sota
# Out:
#            TESTACC       HC2  TS-CHIEF       HC1  InceptionTime    ROCKET  \
# 0            ACSF1  0.930000  0.840000  0.940000       0.910000  0.900000
# 1            Adiac  0.813299  0.797954  0.810742       0.843990  0.769821
# 2        ArrowHead  0.862857  0.805714  0.822857       0.862857  0.794286
# 3             Beef  0.866667  0.766667  0.900000       0.666667  0.833333
# 4        BeetleFly  0.950000  1.000000  0.950000       0.850000  0.900000
# ..             ...       ...       ...       ...            ...       ...
# 107           Wine  0.870370  0.870370  0.796296       0.629630  0.814815
# 108   WordSynonyms  0.752351  0.794671  0.697492       0.744514  0.750784
# 109          Worms  0.753247  0.818182  0.649351       0.805195  0.714286
# 110  WormsTwoClass  0.792208  0.831169  0.766234       0.766234  0.740260
# 111           Yoga  0.934000  0.854333  0.911667       0.905000  0.916667
#
#       Arsenal     DrCIF       TDE       STC
# 0    0.890000  0.880000  0.920000  0.890000
# 1    0.777494  0.820972  0.780051  0.815857
# 2    0.817143  0.805714  0.885714  0.691429
# 3    0.833333  0.766667  0.833333  0.833333
# 4    0.900000  0.900000  1.000000  0.800000
# ..        ...       ...       ...       ...
# 107  0.833333  0.796296  0.666667  0.703704
# 108  0.742947  0.692790  0.763323  0.659875
# 109  0.727273  0.766234  0.727273  0.727273
# 110  0.779221  0.779221  0.766234  0.818182
# 111  0.905333  0.876667  0.926000  0.880667
#
# [112 rows x 10 columns]
