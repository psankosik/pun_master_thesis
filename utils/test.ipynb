# %%
from evaluate import compare_result

# %%
import mlflow
mlflow.set_tracking_uri("/Users/Pongpanod.Sa/Desktop/cu/thesis/coding/pun_master_thesis/mlruns")

# %%
query_list = []

for i in range(1, 21):
    query_list.append({"augment_name":"window_slice", "param_name":"reduce_ratio", "param_value":i/10})
    # query_list = [
    #     {"augment_name":"window_slice", "param_name":"reduce_ratio", "param_value":"1.9"},
    #     {"augment_name":"window_slice", "param_name":"reduce_ratio", "param_value":"1.8"},
    # ]

df = compare_result(query_list)
df
# Out:
# <style type="text/css">
# #T_5cc76_row1_col8, #T_5cc76_row6_col0, #T_5cc76_row6_col4, #T_5cc76_row9_col6, #T_5cc76_row10_col0, #T_5cc76_row10_col1, #T_5cc76_row10_col6, #T_5cc76_row11_col0, #T_5cc76_row11_col6, #T_5cc76_row12_col6, #T_5cc76_row13_col0, #T_5cc76_row13_col5, #T_5cc76_row13_col6, #T_5cc76_row14_col0, #T_5cc76_row14_col1, #T_5cc76_row14_col2, #T_5cc76_row14_col6, #T_5cc76_row15_col0, #T_5cc76_row15_col2, #T_5cc76_row15_col3, #T_5cc76_row15_col6, #T_5cc76_row16_col0, #T_5cc76_row16_col5, #T_5cc76_row16_col6, #T_5cc76_row17_col0, #T_5cc76_row17_col6, #T_5cc76_row18_col0, #T_5cc76_row18_col6, #T_5cc76_row19_col0, #T_5cc76_row19_col2, #T_5cc76_row19_col6, #T_5cc76_row19_col7, #T_5cc76_row20_col0, #T_5cc76_row20_col5, #T_5cc76_row20_col6, #T_5cc76_row20_col9 {
#   color: white;
#   background-color: darkblue;
# }
# </style>
# <table id="T_5cc76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
[i/100 for i in range(1, 102, 4)]
# Out:
# [0.01,
#  0.05,
#  0.09,
#  0.13,
#  0.17,
#  0.21,
#  0.25,
#  0.29,
#  0.33,
#  0.37,
#  0.41,
#  0.45,
#  0.49,
#  0.53,
#  0.57,
#  0.61,
#  0.65,
#  0.69,
#  0.73,
#  0.77,
#  0.81,
#  0.85,
#  0.89,
#  0.93,
#  0.97,
#  1.01]
